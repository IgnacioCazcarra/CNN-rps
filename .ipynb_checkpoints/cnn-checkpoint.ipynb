# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pickle

# %%
pickle_in = open('x.pickle','rb')
x = pickle.load(pickle_in)

pickle_in = open('y.pickle','rb')
y = pickle.load(pickle_in)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, MaxPooling2D, Conv2D, Flatten, Activation, Dropout

# %%
y = keras.utils.to_categorical(y, num_classes=3, dtype="int32")

# %%
model = Sequential()

model.add(Conv2D(64, (3,3), input_shape=x.shape[1:]))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(32, (3,3)))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dense(32))
model.add(Activation("relu"))
model.add(Dropout(0.4))

model.add(Dense(3, activation="softmax"))

# %%
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=['accuracy'])

# %%
history = model.fit(x, y, batch_size=64, validation_split=0.15, epochs=5)
# Out:
# Epoch 1/5
# 39/39 [==============================] - 9s 206ms/step - loss: 1.0847 - accuracy: 0.4051 - val_loss: 0.7046 - val_accuracy: 0.8341
# Epoch 2/5
# 39/39 [==============================] - 8s 206ms/step - loss: 0.5996 - accuracy: 0.7683 - val_loss: 0.2816 - val_accuracy: 0.9147
# Epoch 3/5
# 39/39 [==============================] - 8s 203ms/step - loss: 0.3099 - accuracy: 0.8937 - val_loss: 0.1106 - val_accuracy: 0.9816
# Epoch 4/5
# 39/39 [==============================] - 8s 204ms/step - loss: 0.1898 - accuracy: 0.9373 - val_loss: 0.0627 - val_accuracy: 0.9885
# Epoch 5/5
# 39/39 [==============================] - 8s 204ms/step - loss: 0.1259 - accuracy: 0.9557 - val_loss: 0.0578 - val_accuracy: 0.9793

# %%
import matplotlib.pyplot as plt

# %%
labels = ['train','validation']

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

plt.title('Accuracy')

plt.ylabel('Accuracy')
plt.xlabel('Epochs')

plt.xlim(0,4,1)

plt.legend(labels=labels)

plt.show()

# %%
labels = ['train','validation']

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.title('Loss')

plt.ylabel('Loss')
plt.xlabel('Epochs')

plt.xlim(0,4,1)

plt.legend(labels=labels)

plt.show()

# %%
model.save('CNN-rps.nn')
# Out:
# INFO:tensorflow:Assets written to: CNN-rps.nn\assets

# %%
import cv2

IMG_SIZE = 70

def scale(path):
    image_array = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    new_array = cv2.resize(image_array, (IMG_SIZE,IMG_SIZE))
    return new_array.reshape(-1, IMG_SIZE, IMG_SIZE, 1)

# %%
def get_rps(img):
    if 'rock' in img:
        return 'rock'
    elif 'paper' in img:
        return 'paper'
    else:
        return 'scissors'
    
def get_rps_prediction(arr):
    m = arr[0][0]
    midx = 0
    for i in range(len(arr[0])):
        if m < arr[0][i]:
            m = arr[0][i]
            midx = i
    if midx == 0:
        return 'rock'
    elif midx == 1:
        return 'paper'
    else:
        return 'scissors'

# %%
model = tf.keras.models.load_model('CNN-rps.nn')

# %%
import os

VALIDATIONDIR = "C:/rps-validation"

wrong = 0

for img in os.listdir(VALIDATIONDIR):
    path = os.path.join(VALIDATIONDIR, img)
    image = scale(path)
    
    prediction = model.predict(image)
 
    predicted = get_rps_prediction(prediction)
    actual = get_rps(img)
    
    print(f"Predicted: {predicted} \t Actual: {actual}")
    
    if predicted!=actual:
        wrong+=1
# Out:
# Predicted: paper 	 Actual: paper
# Predicted: paper 	 Actual: paper
# Predicted: paper 	 Actual: paper
# Predicted: paper 	 Actual: paper
# Predicted: paper 	 Actual: paper
# Predicted: paper 	 Actual: paper
# Predicted: paper 	 Actual: paper
# Predicted: paper 	 Actual: paper
# Predicted: paper 	 Actual: paper
# Predicted: paper 	 Actual: paper
# Predicted: paper 	 Actual: paper
# Predicted: rock 	 Actual: rock
# Predicted: rock 	 Actual: rock
# Predicted: rock 	 Actual: rock
# Predicted: rock 	 Actual: rock
# Predicted: rock 	 Actual: rock
# Predicted: rock 	 Actual: rock
# Predicted: rock 	 Actual: rock
# Predicted: rock 	 Actual: rock
# Predicted: rock 	 Actual: rock
# Predicted: rock 	 Actual: rock
# Predicted: rock 	 Actual: rock
# Predicted: scissors 	 Actual: scissors
# Predicted: scissors 	 Actual: scissors
# Predicted: scissors 	 Actual: scissors
# Predicted: scissors 	 Actual: scissors
# Predicted: paper 	 Actual: scissors
# Predicted: scissors 	 Actual: scissors
# ...

# %%
total = len(os.listdir(VALIDATIONDIR))
correct = total - wrong

print(f'Acc of validation set: {correct/total:.2f}')
# Out:
# Acc of validation set: 0.94
